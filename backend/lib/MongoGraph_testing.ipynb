# %%
import sys
sys.path.append('../backend/lib')
sys.path.append('../backend')
from GraphSession import GraphSession
from ResultGraph import ResultGraph
from networkx import generate_gml
import networkx as nx
from networkx.readwrite import json_graph
import json

search_input = 'cancer campbell'

gsession = GraphSession(search_input)

nx_graph = gsession.get_cy_json_mongo(mode='live')
# Out:
# 08/07/2018 08:35:22 PM [INFO]: Created new log.
# 08/07/2018 08:35:23 PM [INFO]: RequestFullTextSearch: Creating request
# 08/07/2018 08:35:23 PM [INFO]: GraphSession: Search input received: cancer campbell
# 08/07/2018 08:35:23 PM [INFO]: Using live mode for data retrieval.
# 08/07/2018 08:35:23 PM [INFO]: ConnectEutils: Connecting to eutils API:
#  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pmc&tool=graphsearch&sort=relevance&term=cancer+campbell&retmax=200
# 08/07/2018 08:35:24 PM [INFO]: Retrieving citation data
# 08/07/2018 08:35:24 PM [INFO]: MongoSession: Mongo db connection successful
# 08/07/2018 08:35:24 PM [INFO]: Populating graph
# 08/07/2018 08:35:25 PM [INFO]: Pruning graph
# 08/07/2018 08:35:25 PM [INFO]: Initialised GraphPruner instance
# 08/07/2018 08:35:25 PM [INFO]: Acquiring meta data
# 08/07/2018 08:35:25 PM [INFO]: Initialised MetaDbConnector instance.
# 08/07/2018 08:35:25 PM [INFO]: MongoSession: Mongo db connection successful
# 08/07/2018 08:35:25 PM [INFO]: Formatting graph for frontend
# 08/07/2018 08:35:25 PM [INFO]: Max degree: 22
# 40

# %%
nx_graph
# Out:
# '{"graph": {"nodes": [{"data": {"node_col": "#ffc6c6", "journal": "Nature", "key": "22722839", "authors": "Grasso, Wu, Robinson", "cite_color": "black", "id": "22722839", "group": "Cited", "name": "22722839", "pubDate": "Jul 2012", "title": "The mutational landscape of lethal  castration-resistant prostate cancer.", "label": "Nature", "journal_iso": "Nature"}}, {"data": {"node_col": "#ff5e5e", "journal": "Scientific reports", "key": "25990418", "authors": "Al-Tassan, Whiffin, Hosking", "cite_color": "black", "id": "25990418", "group": "Cited", "name": "25990418", "pubDate": "May 2015", "title": "A new GWAS and meta-analysis with 1000Genomes imputation identifies novel risk variants for colorectal cancer.", "label": "Scientific reports", "journal_iso": "Sci Rep"}}, {"data": {"node_col": "#ffc6c6", "journal": "Nature", "key": "23770567", "authors": "Lawrence, Stojanov, Polak", "cite_color": "black", "id": "23770567", "group": "Cited", "name": "23770567", "pubDate": "Jul 2013", "title": "Mutational heterogeneity in cancer and the search for new cancer-associated genes.", "label": "Nature", "journal_iso": "Nature"}}, {"data": {"node_col": "#ffbcbc", "journal": "Nature", "key": "23000897", "authors": "", "cite_color": "black", "id": "23000897", "group": "Cited", "name": "23000897", "pubDate": "Oct 2012", "title": "Comprehensive molecular portraits of human breast tumours.", "label": "Nature", "journal_iso": "Nature"}}, {"data": {"node_col": "#ffc6c6", "journal": "Carcinogenesis", "key": "23087083", "authors": "Doig, Singh, Dhiman", "cite_color": "black", "id": "23087083", "group": "Cited", "name": "23087083", "pubDate": "Feb 2013", "title": "Recruitment of NCOR1 to VDR target genes is enhanced in prostate cancer cells and associates with altered DNA methylation patterns.", "label": "Carcinogenesis", "journal_iso": "Carcinogenesis"}}, {"data": {"node_col": "#ffbcbc", "journal": "Nature", "key": "22955616", "authors": "", "cite_color": "black", "id": "22955616", "group": "Cited", "name": "22955616", "pubDate": "Sep 2012", "title": "An integrated encyclopedia of DNA elements in the human genome.", "label": "Nature", "journal_iso": "Nature"}}, {"data": {"node_col": "#ff9c9c", "journal": "Nature genetics", "key": "23535729", "authors": "Michailidou, Hall, Gonzalez-Neira", "cite_color": "black", "id": "23535729", "group": "Cited", "name": "23535729", "pubDate": "Apr 2013", "title": "Large-scale genotyping identifies 41 new loci associated with breast cancer risk.", "label": "Nature genetics", "journal_iso": "Nat. Genet."}}, {"data": {"node_col": "#ffc6c6", "journal": "Nature genetics", "key": "23535722", "authors": "Sakoda, Jorgenson, Witte", "cite_color": "black", "id": "23535722", "group": "Cited", "name": "23535722", "pubDate": "Apr 2013", "title": "Turning of COGS moves forward findings for hormonally mediated cancers.", "label": "Nature genetics", "journal_iso": "Nat. Genet."}}, {"data": {"node_col": "#ffc6c6", "journal": "Nature genetics", "key": "22634755", "authors": "Dunlop, Dobbins, Farrington", "cite_color": "black", "id": "22634755", "group": "Cited", "name": "22634755", "pubDate": "May 2012", "title": "Common variation near CDKN1A, POLD3 and SHROOM2 influences colorectal cancer risk.", "label": "Nature genetics", "journal_iso": "Nat. Genet."}}, {"data": {"node_col": "#ffc6c6", "journal": "Cell", "key": "21376230", "authors": "Hanahan, Weinberg", "cite_color": "black", "id": "21376230", "group": "Cited", "name": "21376230", "pubDate": "Mar 2011", "title": "Hallmarks of cancer: the next generation.", "label": "Cell", "journal_iso": "Cell"}}, {"data": {"node_col": "#ffc6c6", "journal": "Cell", "key": "21215367", "authors": "Stephens, Greenman, Fu", "cite_color": "black", "id": "21215367", "group": "Cited", "name": "21215367", "pubDate": "Jan 2011", "title": "Massive genomic rearrangement acquired in a single catastrophic event during cancer development.", "label": "Cell", "journal_iso": "Cell"}}, {"data": {"node_col": "#ffc6c6" ...
